# %%
import numpy as np
import pandas  as pd

# %%
data = pd.read_csv("housing_price_dataset.csv")

# %%
data
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0            2126         4          1        Rural       1969  215355.283618
# 1            2459         3          2        Rural       1980  195014.221626
# 2            1860         2          1       Suburb       1970  306891.012076
# 3            2294         2          1        Urban       1996  206786.787153
# 4            2130         5          2       Suburb       2001  272436.239065
# ...           ...       ...        ...          ...        ...            ...
# 49995        1282         5          3        Rural       1975  100080.865895
# 49996        2854         2          2       Suburb       1988  374507.656727
# 49997        2979         5          3       Suburb       1962  384110.555590
# 49998        2596         5          2        Rural       1984  380512.685957
# 49999        1572         5          3        Rural       2011  221618.583218
#
# [50000 rows x 6 columns]

# %%
data.head(10)
# Out:
#    SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0        2126         4          1        Rural       1969  215355.283618
# 1        2459         3          2        Rural       1980  195014.221626
# 2        1860         2          1       Suburb       1970  306891.012076
# 3        2294         2          1        Urban       1996  206786.787153
# 4        2130         5          2       Suburb       2001  272436.239065
# 5        2095         2          3       Suburb       2020  198208.803907
# 6        2724         2          1       Suburb       1993  343429.319110
# 7        2044         4          3        Rural       1957  184992.321268
# 8        2638         4          3        Urban       1959  377998.588152
# 9        1121         5          2        Urban       2004   95961.926014

# %%
data.tail(10)
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 49990        2724         5          2       Suburb       1978  395026.724290
# 49991        1952         5          3       Suburb       1981  200237.485880
# 49992        1818         4          1        Rural       1983  163683.675434
# 49993        1215         2          3        Urban       2017  126052.390562
# 49994        2426         5          2        Urban       1950  331497.091307
# 49995        1282         5          3        Rural       1975  100080.865895
# 49996        2854         2          2       Suburb       1988  374507.656727
# 49997        2979         5          3       Suburb       1962  384110.555590
# 49998        2596         5          2        Rural       1984  380512.685957
# 49999        1572         5          3        Rural       2011  221618.583218

# %%
data.describe()
# Out:
#          SquareFeet      Bedrooms     Bathrooms     YearBuilt          Price
# count  50000.000000  50000.000000  50000.000000  50000.000000   50000.000000
# mean    2006.374680      3.498700      1.995420   1985.404420  224827.325151
# std      575.513241      1.116326      0.815851     20.719377   76141.842966
# min     1000.000000      2.000000      1.000000   1950.000000  -36588.165397
# 25%     1513.000000      3.000000      1.000000   1967.000000  169955.860225
# 50%     2007.000000      3.000000      2.000000   1985.000000  225052.141166
# 75%     2506.000000      4.000000      3.000000   2003.000000  279373.630052
# max     2999.000000      5.000000      3.000000   2021.000000  492195.259972

# %%
data.shape
# Out:
# (50000, 6)

# %%
data.info
# Out:
# <bound method DataFrame.info of        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0            2126         4          1        Rural       1969  215355.283618
# 1            2459         3          2        Rural       1980  195014.221626
# 2            1860         2          1       Suburb       1970  306891.012076
# 3            2294         2          1        Urban       1996  206786.787153
# 4            2130         5          2       Suburb       2001  272436.239065
# ...           ...       ...        ...          ...        ...            ...
# 49995        1282         5          3        Rural       1975  100080.865895
# 49996        2854         2          2       Suburb       1988  374507.656727
# 49997        2979         5          3       Suburb       1962  384110.555590
# 49998        2596         5          2        Rural       1984  380512.685957
# 49999        1572         5          3        Rural       2011  221618.583218
#
# ...

# %%
data.groupby(["Bedrooms"]).count()
# Out:
#           SquareFeet  Bathrooms  Neighborhood  YearBuilt  Price
# Bedrooms
# 2              12436      12436         12436      12436  12436
# 3              12661      12661         12661      12661  12661
# 4              12435      12435         12435      12435  12435
# 5              12468      12468         12468      12468  12468

# %%
data.groupby(['Bathrooms']).count()
# Out:
#            SquareFeet  Bedrooms  Neighborhood  YearBuilt  Price
# Bathrooms
# 1               16755     16755         16755      16755  16755
# 2               16719     16719         16719      16719  16719
# 3               16526     16526         16526      16526  16526

# %%
data.groupby(['YearBuilt']).count()
# Out:
#            SquareFeet  Bedrooms  Bathrooms  Neighborhood  Price
# YearBuilt
# 1950              643       643        643           643    643
# 1951              698       698        698           698    698
# 1952              723       723        723           723    723
# 1953              685       685        685           685    685
# 1954              704       704        704           704    704
# ...               ...       ...        ...           ...    ...
# 2017              692       692        692           692    692
# 2018              704       704        704           704    704
# 2019              662       662        662           662    662
# 2020              704       704        704           704    704
# 2021              648       648        648           648    648
#
# [72 rows x 5 columns]

# %%
data["Bedrooms"].unique()
# Out:
# array([4, 3, 2, 5], dtype=int64)

# %%
data=pd.get_dummies(data,dtype=int)

# %%
data
# Out:
#        SquareFeet  Bedrooms  Bathrooms  YearBuilt          Price  \
# 0            2126         4          1       1969  215355.283618
# 1            2459         3          2       1980  195014.221626
# 2            1860         2          1       1970  306891.012076
# 3            2294         2          1       1996  206786.787153
# 4            2130         5          2       2001  272436.239065
# ...           ...       ...        ...        ...            ...
# 49995        1282         5          3       1975  100080.865895
# 49996        2854         2          2       1988  374507.656727
# 49997        2979         5          3       1962  384110.555590
# 49998        2596         5          2       1984  380512.685957
# 49999        1572         5          3       2011  221618.583218
#
#        Neighborhood_Rural  Neighborhood_Suburb  Neighborhood_Urban
# 0                       1                    0                   0
# ...

# %%
d1=data

# %%
d1
# Out:
#        SquareFeet  Bedrooms  Bathrooms  YearBuilt          Price  \
# 0            2126         4          1       1969  215355.283618
# 1            2459         3          2       1980  195014.221626
# 2            1860         2          1       1970  306891.012076
# 3            2294         2          1       1996  206786.787153
# 4            2130         5          2       2001  272436.239065
# ...           ...       ...        ...        ...            ...
# 49995        1282         5          3       1975  100080.865895
# 49996        2854         2          2       1988  374507.656727
# 49997        2979         5          3       1962  384110.555590
# 49998        2596         5          2       1984  380512.685957
# 49999        1572         5          3       2011  221618.583218
#
#        Neighborhood_Rural  Neighborhood_Suburb  Neighborhood_Urban
# 0                       1                    0                   0
# ...

# %%
core=d1.corr()
core
# Out:
#                      SquareFeet  Bedrooms  Bathrooms  YearBuilt     Price  \
# SquareFeet             1.000000 -0.002638  -0.003275   0.000482  0.750720
# Bedrooms              -0.002638  1.000000   0.007405   0.003147  0.072624
# Bathrooms             -0.003275  0.007405   1.000000   0.003748  0.028418
# YearBuilt              0.000482  0.003147   0.003748   1.000000 -0.002288
# Price                  0.750720  0.072624   0.028418  -0.002288  1.000000
# Neighborhood_Rural    -0.005843  0.005156  -0.003672  -0.001747 -0.006793
# Neighborhood_Suburb   -0.007665 -0.003029   0.004551   0.003793 -0.014831
# Neighborhood_Urban     0.013528 -0.002127  -0.000883  -0.002051  0.021658
#
#                      Neighborhood_Rural  Neighborhood_Suburb  \
# SquareFeet                    -0.005843            -0.007665
# Bedrooms                       0.005156            -0.003029
# Bathrooms                     -0.003672             0.004551
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(core,vmax=1,vmin=0,annot=True,linewidth=5,cmap='bwr')
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
plt.hist(data["Price"])
# Out:
# (array([   57.,   766.,  3845.,  8894., 12107., 12082.,  8324.,  3308.,
#           580.,    37.]),
#  array([-36588.16539749,  16290.17713946,  69168.51967641, 122046.86221336,
#         174925.20475031, 227803.54728726, 280681.88982421, 333560.23236116,
#         386438.57489811, 439316.91743506, 492195.25997202]),
#  <BarContainer object of 10 artists>)

# %%
y=d1["Price"]
x=d1.drop(["Price"],axis=1)

# %%
y
# Out:
# 0        215355.283618
# 1        195014.221626
# 2        306891.012076
# 3        206786.787153
# 4        272436.239065
#              ...
# 49995    100080.865895
# 49996    374507.656727
# 49997    384110.555590
# 49998    380512.685957
# 49999    221618.583218
# Name: Price, Length: 50000, dtype: float64

# %%
x
# Out:
#        SquareFeet  Bedrooms  Bathrooms  YearBuilt  Neighborhood_Rural  \
# 0            2126         4          1       1969                   1
# 1            2459         3          2       1980                   1
# 2            1860         2          1       1970                   0
# 3            2294         2          1       1996                   0
# 4            2130         5          2       2001                   0
# ...           ...       ...        ...        ...                 ...
# 49995        1282         5          3       1975                   1
# 49996        2854         2          2       1988                   0
# 49997        2979         5          3       1962                   0
# 49998        2596         5          2       1984                   1
# 49999        1572         5          3       2011                   1
#
#        Neighborhood_Suburb  Neighborhood_Urban
# 0                        0                   0
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.33,random_state=42)

# %%
x_train
# Out:
#        SquareFeet  Bedrooms  Bathrooms  YearBuilt  Neighborhood_Rural  \
# 23990        2561         3          1       2019                   1
# 8729         1064         5          1       2016                   1
# 3451         2756         4          2       1967                   0
# 2628         1731         4          2       2015                   1
# 38352        2794         5          1       1992                   0
# ...           ...       ...        ...        ...                 ...
# 11284        2166         5          3       1996                   0
# 44732        2463         4          1       1953                   0
# 38158        2812         4          2       2010                   0
# 860          2188         3          1       1979                   0
# 15795        2649         5          3       1953                   1
#
#        Neighborhood_Suburb  Neighborhood_Urban
# 23990                    0                   0
# ...

# %%
x_test
# Out:
#        SquareFeet  Bedrooms  Bathrooms  YearBuilt  Neighborhood_Rural  \
# 33553        1894         5          1       1975                   1
# 9427         1001         5          3       1963                   0
# 199          2264         4          3       1964                   0
# 12447        2299         5          1       1999                   0
# 39489        2651         2          1       1951                   0
# ...           ...       ...        ...        ...                 ...
# 27615        2647         2          3       1951                   1
# 21964        1300         3          3       1958                   0
# 33321        1181         5          1       2003                   0
# 40225        2513         2          1       1995                   1
# 28203        2899         2          3       1960                   0
#
#        Neighborhood_Suburb  Neighborhood_Urban
# 33553                    0                   0
# ...

# %%
y_train
# Out:
# 23990    365384.363339
# 8729      98914.614596
# 3451     265441.025324
# 2628     248259.953718
# 38352    286485.264621
#              ...
# 11284    324396.846219
# 44732    319266.944411
# 38158    248092.662727
# 860      132414.177622
# 15795    288751.049986
# Name: Price, Length: 33500, dtype: float64

# %%
y_test
# Out:
# 33553    170835.035713
# 9427     126913.469998
# 199      246611.883092
# 12447    244250.462969
# 39489    271127.650112
#              ...
# 27615    291504.040710
# 21964    193917.029039
# 33321    118758.460607
# 40225    259968.166763
# 28203    289685.873746
# Name: Price, Length: 16500, dtype: float64

# %%
x_train.shape
# Out:
# (33500, 7)

# %%
x_test.shape
# Out:
# (16500, 7)

# %%
y_train.shape
# Out:
# (33500,)

# %%
y_test.shape
# Out:
# (16500,)

# %%
from sklearn.linear_model import LinearRegression
panda=LinearRegression()
panda.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred= panda.predict(x_test)

# %%
y_pred
# Out:
# array([218038.82185779, 134717.32539269, 255121.74154988, ...,
#        148987.75620639, 264005.4065916 , 307781.18375265])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.5724989899555579

# %%
Results=pd.DataFrame(columns=['Price','Predicted'])
Results['Price']=y_test
Results['Predicted']=y_pred

# %%
Results
# Out:
#                Price      Predicted
# 33553  170835.035713  218038.821858
# 9427   126913.469998  134717.325393
# 199    246611.883092  255121.741550
# 12447  244250.462969  258048.074657
# 39489  271127.650112  277052.363912
# ...              ...            ...
# 27615  291504.040710  283080.721460
# 21964  193917.029039  156079.161650
# 33321  118758.460607  148987.756206
# 40225  259968.166763  264005.406592
# 28203  289685.873746  307781.183753
#
# [16500 rows x 2 columns]

# %%
Results=Results.reset_index()

# %%
Results
# Out:
#        index          Price      Predicted
# 0      33553  170835.035713  218038.821858
# 1       9427  126913.469998  134717.325393
# 2        199  246611.883092  255121.741550
# 3      12447  244250.462969  258048.074657
# 4      39489  271127.650112  277052.363912
# ...      ...            ...            ...
# 16495  27615  291504.040710  283080.721460
# 16496  21964  193917.029039  156079.161650
# 16497  33321  118758.460607  148987.756206
# 16498  40225  259968.166763  264005.406592
# 16499  28203  289685.873746  307781.183753
#
# [16500 rows x 3 columns]

# %%
Results['ID']=Results.index

# %%
Results
# Out:
#        index          Price      Predicted     ID
# 0      33553  170835.035713  218038.821858      0
# 1       9427  126913.469998  134717.325393      1
# 2        199  246611.883092  255121.741550      2
# 3      12447  244250.462969  258048.074657      3
# 4      39489  271127.650112  277052.363912      4
# ...      ...            ...            ...    ...
# 16495  27615  291504.040710  283080.721460  16495
# 16496  21964  193917.029039  156079.161650  16496
# 16497  33321  118758.460607  148987.756206  16497
# 16498  40225  259968.166763  264005.406592  16498
# 16499  28203  289685.873746  307781.183753  16499
#
# [16500 rows x 4 columns]

# %%
sns.lineplot(x='ID',y='Price',data=Results.head(50))
sns.lineplot(x="ID",y="Predicted",data=Results.head(50))
plt.plot()
# Out:
# []

# %%
new=[[2500,3,2,2005,1,0,0,]]
real=panda.predict(new)
real
# Out:
# C:\Users\HI\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([271016.64239835])
